# %%
import requests

r = requests.get("https://raw.githubusercontent.com/psf/requests/main/setup.cfg")

r.text

def check_update():
    r = requests.get("https://raw.githubusercontent.com/parthk5/SpellingBeeGame/main/version.txt")
    latest = int(r.text.replace(".", ""))

    with open("version.txt", 'r') as verFile:
        currVer = int(verFile.read().replace(".", ""))

    #print(f"Latest: {latest}")
    #print(f"Current: {currVer}")

    return latest > currVer

check_update()
# Out:
# '\n\n\n\n\n\n\n<!DOCTYPE html>\n<html\n  lang="en"\n  \n  data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"\n  data-a11y-animated-images="system" data-a11y-link-underlines="true"\n  >\n\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-38f1bf52eeeb.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-56010aa53a8f.css" /><link data-color-theme="dark_dim
# ...

# %%
import os
os.environ["USER"]
# Out:
# 'parthkhanna'

# %%
from git import Repo
from platform import system
import os

def download(versionID):
    if system() == "Darwin"
       download_dir = f"/Users/{os.environ['USER']}/Desktop/SBG-{versionID}"
    Repo.clone_from("https://github.com/parthk5/SpellingBeeGame", download_dir)
# Out:
# Darwin

# %%
from subprocess import Popen
import sys

def run_update(mainPATH):
    os.system(f"python3 {mainPATH}", shell=True)

run_update(sys.argv[0])
exit("Applying Update")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# <>:4: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/hq/1k37v2vd5j562dg2218t_8bm0000gn/T/ipykernel_64001/2615436252.py:4: SyntaxWarning: invalid escape sequence '\ '
#   Popen("python3 /Users/parthkhanna/Documents/Python\ Scripts/AnjuSpellingBee/main.py", shell=True)
# Applying past metrics:
# {'doctor': 0.1, 'sprocket': 0.1, 'Trinidadian': 0.7, 'hair': 0.1, 'Macedonia': 0.1, 'Shaanxi': 0.7, 'wafting': 0.1, 'frijoles': 0.1}
# Using native tts
# Starting with learning curve
# Found the following scores to adapt to:
# {'doctor': 0.1, 'sprocket': 0.1, 'Trinidadian': 0.7, 'hair': 0.1, 'Macedonia': 0.1, 'Shaanxi': 0.7, 'wafting': 0.1, 'frijoles': 0.1}

# %%
import shutil
import os
import sys
import stat

def remove_readonly(func, path, _):
    "Clear the readonly bit and reattempt the removal"
    os.chmod(path, stat.S_IWRITE)
    func(path)


def install(installPath):
    updatePATH = os.getcwd().split("/")[-1]
    os.system("cd ..")

    if os.path.exists(installPath):
        shutil.rmtree(installPath)
    
    shutil.copy(updatePATH, installPath)
    exit("Update Applied")

install(sys.argv[1])
# Out:
# Received: /Users/parthkhanna/Documents/Python Scripts/AnjuSpellingBee/test.py
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# <>:1: SyntaxWarning: invalid escape sequence '\ '
# /var/folders/hq/1k37v2vd5j562dg2218t_8bm0000gn/T/ipykernel_64001/650840079.py:1: SyntaxWarning: invalid escape sequence '\ '
#   os.system("python3 /Users/parthkhanna/Documents/Python\ Scripts/AnjuSpellingBee/test.py hello")
# 0
